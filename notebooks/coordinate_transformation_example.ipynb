# %%
import sys
import os

# Of course, use your own path to the tools
sys.path.append(os.path.abspath("/mnt/netapp2/Store_uni/home/usc/ie/dcr/analysis_tools/analysis_tools"))

from wcsim_wcte_coordinate_transformation import coordinateTransform

# %% [markdown]
# # WCSim to WCTE

# %%
# Create instance
ct = coordinateTransform()

# Define your set of WCSim coordinates in mm!
wcsim_coords = [0,0,0] # The center of the tank in WCSim

wcte_coords = ct.wcsim_to_wcte(wcsim_coords)

print(wcte_coords)
# Out:
# [  0.     424.7625   0.    ]

# %%
# Create instance
ct = coordinateTransform()

# Define your set of WCSim coordinates in mm!
wcsim_coords = [-476.4, -452.9, 291.7] # The center of the tank in WCSim

wcte_coords = ct.wcsim_to_wcte(wcsim_coords)

print(wcte_coords)
# Out:
# [-476.4     -28.1375  291.7   ]

# %% [markdown]
# # WCTE to WCSim

# %%
# Create instance
ct = coordinateTransform()

# Define your set of WCTE coordinates
wcte_coords = [0,424.7625,0] # The center of the tank in WCTE

wcsim_coords = ct.wcte_to_wcsim(wcte_coords)

print(wcsim_coords)
# Out:
# [0. 0. 0.]

# %%
# Define your set of WCTE coordinates
wcte_coords = [0,1525,0] # The top of the tank in WCTE

wcsim_coords = ct.wcte_to_wcsim(wcte_coords)

print(wcsim_coords)
# Out:
# [   0.     1100.2375    0.    ]

# %%
# Define your set of WCTE coordinates
wcte_coords = [0,-1100,0] # The bottom of the tank in WCTE

wcsim_coords = ct.wcte_to_wcsim(wcte_coords)

print(wcsim_coords)
# Out:
# [    0.     -1524.7625     0.    ]
